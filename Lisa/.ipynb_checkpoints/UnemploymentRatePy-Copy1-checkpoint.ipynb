# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import requests
import json

import pandas as pd
import os
import csv
import numpy as np
#from uszipcode import SearchEngine
#import plotly.plotly as py
#import plotly.graph_objs as go

# %%
print("Working on unemployment data")
# Out:
# Working on unemployment data

# %%
# # working on unemployment data from department of labor
# # Save path to data set in a variable

# #2019
# unemploymentDataFile2019 = "source/unemploymentData/19aasub_csv.csv"
# # Use Pandas to read data
# unemploymentDataFile2019_pd = pd.read_csv(unemploymentDataFile2019)
# unemploymentDataFile2019_pd.head()

# %%
#2018
# Save path to data set in a variable
unemploymentDataFile2018 = "source/unemploymentData/18aasub_csv.csv"

# Use Pandas to read data
unemploymentDataFile2018_pd = pd.read_csv(unemploymentDataFile2018)
unemploymentDataFile2018_pd.head()
# Out:
#             AreaName Labor-Force Employment Unemployment-Number  \
# 0       Alameda city      42,100     40,900               1,200
# 1        Albany city       9,900      9,700                 200
# 2        Ashland CDP      11,500     10,900                 500
# 3      Berkeley city      63,600     61,800               1,800
# 4  Castro Valley CDP      32,700     31,800                 900
#
#   Unemployment-Rate  CensusRatios-Emp  CensusRatios-Unemp
# 0             2.80%               NaN                 NaN
# 1             2.30%          0.011767            0.008876
# 2             4.80%          0.013267            0.021457
# 3             2.80%               NaN                 NaN
# 4             2.80%          0.038673            0.035581

# %%
#2017
# Save path to data set in a variable
unemploymentDataFile2017 = "source/unemploymentData/17aasub_csv.csv"

# Use Pandas to read data
unemploymentDataFile2017_pd = pd.read_csv(unemploymentDataFile2017)
unemploymentDataFile2017_pd.head()
# Out:
#                                             AreaName Labor-Force Employment  \
# 0  Alameda County                                ...     840,200    809,400
# 1                                       Alameda city      41,700     40,300
# 2                                        Albany city       9,800      9,500
# 3                                        Ashland CDP      11,400     10,700
# 4                                      Berkeley city      63,000     60,800
#
#   Unemployment-Number Unemployment-Rate  CensusRatios-Emp  CensusRatios-Unemp
# 0              30,900             3.70%          1.000000            1.000000
# 1               1,400             3.50%               NaN                 NaN
# 2                 300             2.80%          0.011767            0.008876
# 3                 700             5.80%          0.013267            0.021457
# 4               2,200             3.50%               NaN                 NaN

# %%
#2016
# Save path to data set in a variable
unemploymentDataFile2016 = "source/unemploymentData/16aasub_csv.csv"

# Use Pandas to read data
unemploymentDataFile2016_pd = pd.read_csv(unemploymentDataFile2016)
unemploymentDataFile2016_pd.head()
# Out:
#                                             AreaName Labor-Force Employment  \
# 0  Alameda County                                ...     832,500    796,800
# 1                                       Alameda city      41,500     39,900
# 2                                        Albany city       9,300      8,900
# 3                                        Ashland CDP      11,100     10,300
# 4                                      Berkeley city      62,400     59,800
#
#   Unemployment-Number Unemployment-Rate  CensusRatios-Emp  Census Ratios-Unemp
# 0              35,700             4.30%          1.000000             1.000000
# 1               1,600             4.00%               NaN                  NaN
# 2                 300             3.70%          0.011198             0.009560
# 3                 800             7.30%          0.012884             0.022633
# 4               2,500             4.00%               NaN                  NaN

# %%
#unemploymentDataFile2019_pd["AreaName"][66]

# %%
#Look for AreaName='Los Angeles city' in  2018, 2017, and 2016
#Put those rows in a new dataframe

areaNameList = []
laborForceList = []
employmentList = []
unemploymentNumberList = []
unemploymentRateList = []
yearList = []

# year=2019
# for index, row in unemploymentDataFile2019_pd.iterrows():
#     #print(f'{index}, {row}')
#     ###
#     ###print(index, row['AreaName'], row['Labor-Force'], row['Employment'], row['Unemployment-Number'], row['Unemployment-Rate'])
#         #print(f'{index}, {row}')
#     if (row['AreaName'] == 'Los Angeles city'):
#          #print("here: " + row['AreaName'])
#          areaNameList.append(row['AreaName'])
#          laborForceList.append(row['Labor-Force'])
#          employmentList.append(row['Employment'])
#          unemploymentNumberList.append(row['Unemployment-Number'])
#          unemploymentRateList.append(row['Unemployment-Rate'])
#          yearList.append(int(year))
# #print(areaNameList, yearList)


year=2018
for index, row in unemploymentDataFile2018_pd.iterrows():
    #print(f'{index}, {row}')
    ###
    ###print(index, row['AreaName'], row['Labor-Force'], row['Employment'], row['Unemployment-Number'], row['Unemployment-Rate'])
        #print(f'{index}, {row}')
    if (row['AreaName'] == 'Los Angeles city'):
         #print("here: " + row['AreaName'])
         areaNameList.append(row['AreaName'])
         laborForceList.append(row['Labor-Force'])
         employmentList.append(row['Employment'])
         unemploymentNumberList.append(row['Unemployment-Number'])
         unemploymentRateList.append(row['Unemployment-Rate'])
         yearList.append(int(year))
#print(areaNameList, yearList)


year=2017
for index, row in unemploymentDataFile2017_pd.iterrows():
    #print(f'{index}, {row}')
    ###
    ###print(index, row['AreaName'], row['Labor-Force'], row['Employment'], row['Unemployment-Number'], row['Unemployment-Rate'])
        #print(f'{index}, {row}')
    if (row['AreaName'] == 'Los Angeles city'):
         #print("here: " + row['AreaName'])
         areaNameList.append(row['AreaName'])
         laborForceList.append(row['Labor-Force'])
         employmentList.append(row['Employment'])
         unemploymentNumberList.append(row['Unemployment-Number'])
         unemploymentRateList.append(row['Unemployment-Rate'])
         yearList.append(int(year))
#print(areaNameList, yearList)



year=2016
for index, row in unemploymentDataFile2016_pd.iterrows():
    #print(f'{index}, {row}')
    ###
    ###print(index, row['AreaName'], row['Labor-Force'], row['Employment'], row['Unemployment-Number'], row['Unemployment-Rate'])
        #print(f'{index}, {row}')
    if (row['AreaName'] == 'Los Angeles city'):
         #print("here: " + row['AreaName'])
         areaNameList.append(row['AreaName'])
         laborForceList.append(row['Labor-Force'])
         employmentList.append(row['Employment'])
         unemploymentNumberList.append(row['Unemployment-Number'])
         unemploymentRateList.append(row['Unemployment-Rate'])
         yearList.append(int(year))
print(areaNameList, yearList)

## create new data frame
unemployment_2016_2018_data = {'AreaName': areaNameList,'LaborForce': laborForceList, 'Employment' : employmentList, 'UnemploymentNumber' : unemploymentNumberList, 'UnemploymentRate' : unemploymentRateList, 'Year' : yearList}
unemployment_2016_2018_df = pd.DataFrame(unemployment_2016_2018_data)
unemployment_2016_2018_df
unemployment_2016_2018_df.to_csv("output/combined_unemployment_2016_2018.csv", index=False, header=True)
# Out:
# ['Los Angeles city', 'Los Angeles city', 'Los Angeles city'] [2018, 2017, 2016]

# %%
unemployment_2016_2018_df
# Out:
#            AreaName LaborForce Employment UnemploymentNumber UnemploymentRate  \
# 0  Los Angeles city  2,080,200  1,982,600             97,600            4.70%
# 1  Los Angeles city  2,064,100  1,965,300             98,800            4.80%
# 2  Los Angeles city  2,034,500  1,927,600            106,900            5.30%
#
#    Year
# 0  2018
# 1  2017
# 2  2016

# %%
###
#year vs unemployment rate Plot
# Build a scatter plot for each data type

laborForceForSize = []
for x in unemployment_2016_2018_df["LaborForce"]:
   # print(x.replace(",", ""))
    x = x.replace(",", "")
    laborForceForSize.append(int(x)/10000)
#unemployment_2016_2019_df["LaborForce"]
#print(f' laborForceForSize: {laborForceForSize}')


plt.scatter(unemployment_2016_2018_df["Year"], 
            unemployment_2016_2018_df["UnemploymentRate"],
            s=laborForceForSize,
            edgecolor="black", linewidths=1, marker="o", alpha=0.7)

# Incorporate the other graph properties
plt.title("LA City Unemployment Rate (2016-2018)")
plt.ylabel("Unemployment Rate (%)")
plt.xlabel("Year")
plt.grid(True)
plt.xlim(2015,2019,1)
plt.ylim(-1, 3)

# Save the figure
plt.savefig("./output/LA_unemployment_rate_2016_2018.png")

# Show plot
plt.show()

# %%
## test
data = [8,12,15,17,18,18.5]
perc = np.linspace(0,100,len(data))

fig = plt.figure(1, (7,4))
ax = fig.add_subplot(1,1,1)

ax.plot(perc, data)

fmt = '%.0f%%' # Format you want the ticks, e.g. '40%'
xticks = mtick.FormatStrFormatter(fmt)
ax.xaxis.set_major_formatter(xticks)

plt.show()

# %%
print("End of working on Unemployment Data")
# Out:
# End of working on Unemployment Data

# %%
print("End of working on Foreclousure Data")
# Out:
# End of working on Foreclousure Data

# %%
# # working on foreclosure data from Data.lacity.org
# # Save path to data set in a variable

# #2019
# foreclosureDataFile2019 = "source/ForeclosureData/2019_Registered_Foreclosure_Properties.csv"
# # Use Pandas to read data
# foreclosureDataFile2019_pd = pd.read_csv(foreclosureDataFile2019)
# foreclosureDataFile2019_pd.head()
# Out:
#           APN Registered Date       Property Type     Property Address  \
# 0  2126038013        1/2/2019        Multi-Family     18553 W LEMAY ST
# 1  2378025032       1/10/2019  Vacant Residential      3801 N BERRY DR
# 2  2510022010       2/14/2019       Single Family  13420 N WHEELER AVE
# 3  2378025027       1/10/2019       Single Family      3779 N BERRY DR
# 4  2034001021       1/21/2019       Single Family    23727 W WELBY WAY
#
#   Property City Property State  Property Zip  Council District  \
# 0   LOS ANGELES             CA         91335                 3
# 1   LOS ANGELES             CA         91604                 2
# 2   LOS ANGELES             CA         91342                 7
# 3   LOS ANGELES             CA         91604                 2
# 4   LOS ANGELES             CA         91307                12
#
#                               Lender
# 0            NORTH SHORE CAPITAL INC
# 1     Kodiak Capital Management, LLC
# 2                             Celink
# ...

# %%
# working on foreclosure data from Data.lacity.org
# Save path to data set in a variable

#2018
foreclosureDataFile2018 = "source/ForeclosureData/2018_Registered_Foreclosure_Properties.csv"
# Use Pandas to read data
foreclosureDataFile2018_pd = pd.read_csv(foreclosureDataFile2018)
foreclosureDataFile2018_pd.head()
# Out:
#           APN Registered Date  Property Type     Property Address  \
# 0  6003016019      10/31/2018   Multi-Family       1217 W 60TH PL
# 1  2151015040       11/1/2018  Single Family  20519 W HATTERAS ST
# 2  5442030015       11/5/2018  Single Family      2801 N MARSH ST
# 3  5015020012       1/17/2018   Multi-Family       2071 W 52ND ST
# 4  7416002028        1/5/2018  Single Family    649 N FRIGATE AVE
#
#   Property City Property State  Property Zip  Council District  \
# 0   LOS ANGELES             CA       90044.0                 9
# 1   LOS ANGELES             CA       91367.0                 3
# 2   LOS ANGELES             CA       90039.0                13
# 3   LOS ANGELES             CA       90062.0                 8
# 4   LOS ANGELES             CA       90744.0                15
#
#                                   Lender  Unnamed: 9  Unnamed: 10  \
# 0                   JCAP Financial Group         NaN          NaN
# ...

# %%
# working on foreclosure data from Data.lacity.org
# Save path to data set in a variable

#2017
foreclosureDataFile2017 = "source/ForeclosureData/2017_Registered_Foreclosure_Properties.csv"
# Use Pandas to read data
foreclosureDataFile2017_pd = pd.read_csv(foreclosureDataFile2017)
foreclosureDataFile2017_pd.head()
# Out:
#           APN RegisteredDate   PropertyType  \
# 0  7559031001      3/14/2017  Single Family
# 1  2617013015      1/23/2017  Single Family
# 2  6074014045       2/3/2017   Multi-Family
# 3  5690019023      2/16/2017  Single Family
# 4  5543023022      6/20/2017  Single Family
#
#                                      PropertyAddress PropertyCity  \
# 0  635 S BYNNER DR\r\nSAN PEDRO, CA 90732\r\n(33....    SAN PEDRO
# 1  14290 W MINNEHAHA ST\r\nLOS ANGELES, CA 91345\...  LOS ANGELES
# 2  221 1/2 W 110TH ST\r\nLOS ANGELES, CA 90061\r\...  LOS ANGELES
# 3  4858 N GLACIER DR\r\nLOS ANGELES, CA 90041\r\n...  LOS ANGELES
# 4  1337 N KENMORE AVE\r\nLOS ANGELES, CA 90027\r\...  LOS ANGELES
#
#   PropertyState  PropertyZip  CouncilDistrict  \
# 0            CA        90732               15
# 1            CA        91345                7
# 2            CA        90061                8
# 3            CA        90041               14
# 4            CA        90027               13
#
# ...

# %%
# working on foreclosure data from Data.lacity.org
# Save path to data set in a variable

#2016
foreclosureDataFile2016 = "source/ForeclosureData/2016_Registered_Foreclosure_Properties.csv"
# Use Pandas to read data
foreclosureDataFile2016_pd = pd.read_csv(foreclosureDataFile2016)
foreclosureDataFile2016_pd.head()
# Out:
#           APN RegisteredDate   PropertyType  \
# 0  2601071034       1/2/2016  Single Family
# 1  5570001008       1/7/2016  Single Family
# 2  6119024008      11/7/2016  Single Family
# 3  2631026015     12/14/2016  Single Family
# 4  2254027011     11/23/2016  Single Family
#
#                                      PropertyAddress PropertyCity  \
# 0  17725 W ORNA DR\r\nLOS ANGELES, CA 91344\r\n(3...  LOS ANGELES
# 1  2695 N LA CUESTA DR\r\nLOS ANGELES, CA 90046\r...  LOS ANGELES
# 2  841 W 148TH ST\r\nLOS ANGELES, CA 90247\r\n(33...  LOS ANGELES
# 3  11826 W SNELLING ST\r\nLOS ANGELES, CA 91352\r...  LOS ANGELES
# 4        17431 W EMILITA ST\r\nLOS ANGELES, CA 91316  LOS ANGELES
#
#   PropertyState  PropertyZip  CouncilDistrict  \
# 0            CA        91344               12
# 1            CA        90046                4
# 2            CA        90247               15
# 3            CA        91352                6
# 4            CA        91316                5
#
# ...

# %%
print("Working on Crime Data")
# Out:
# Working on Crime Data

# %%
# # working on crime data from Data.lacity.org
# # Save path to data set in a variable

# #2019
# crimeDataFile2019 = "source/CrimeData/2019_Crime_Data_LA.csv"
# # Use Pandas to read data
# crimeDataFile2019_pd = pd.read_csv(crimeDataFile2019)
# crimeDataFile2019_pd.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  191104106      1/1/2019     10/3/2015           2030       11    Northeast
# 1  191504002      1/1/2019    11/26/2017           1200       15  N Hollywood
# 2  190204109      1/2/2019     12/1/2016            800        2      Rampart
# 3  190904063      1/2/2019      8/1/2016           1535        9     Van Nuys
# 4  191604029      1/2/2019     6/30/2016            200       16     Foothill
#
#    Reporting District  Crime Code       Crime Code Description  \
# 0                1102         860  BATTERY WITH SEXUAL CONTACT
# 1                1512         354            THEFT OF IDENTITY
# 2                 202         662           BUNCO, GRAND THEFT
# 3                 952         310                     BURGLARY
# 4                1622         121               RAPE, FORCIBLE
#
#                                   MO Codes  ...  \
# 0                           0522 0558 1259  ...
# ...

# %%
# working on crime data from Data.lacity.org
# Save path to data set in a variable

#2018
crimeDataFile2018 = "source/CrimeData/2018_Crime_Data_LA.csv"
# Use Pandas to read data
crimeDataFile2018_pd = pd.read_csv(crimeDataFile2018)
crimeDataFile2018_pd.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID  Area Name  \
# 0  182104017      1/1/2018     12/1/2016           1200       21    Topanga
# 1  170626388      1/1/2018    12/31/2017           2355        6  Hollywood
# 2  170902160      1/1/2018    12/29/2017           1730        9   Van Nuys
# 3  180104007      1/1/2018    12/31/2017           2110        1    Central
# 4  180104012      1/1/2018    12/31/2017           1900        1    Central
#
#    Reporting District  Crime Code  \
# 0                2196         354
# 1                 646         624
# 2                 969         310
# 3                 122         330
# 4                 122         420
#
#                             Crime Code Description  \
# 0                                THEFT OF IDENTITY
# 1                         BATTERY - SIMPLE ASSAULT
# 2                                         BURGLARY
# 3                            BURGLARY FROM VEHICLE
# ...

# %%
# working on crime data from Data.lacity.org
# Save path to data set in a variable

#2017
crimeDataFile2017 = "source/CrimeData/2017_Crime_Data_LA.csv"
# Use Pandas to read data
crimeDataFile2017_pd = pd.read_csv(crimeDataFile2017)
crimeDataFile2017_pd.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID  Area Name  \
# 0  171404023      1/1/2017    12/23/2015           1400       14    Pacific
# 1  160601639      1/1/2017    12/29/2016           2305        6  Hollywood
# 2  160601645      1/1/2017    12/31/2016             15        6  Hollywood
# 3  160601649      1/1/2017    12/31/2016           1620        6  Hollywood
# 4  160601650      1/1/2017    12/31/2016            345        6  Hollywood
#
#    Reporting District  Crime Code  \
# 0                1433         341
# 1                 642         946
# 2                 621         745
# 3                 643         930
# 4                 645         210
#
#                               Crime Code Description  \
# 0  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...
# 1                          OTHER MISCELLANEOUS CRIME
# 2           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 3             CRIMINAL THREATS - NO WEAPON DISPLAYED
# ...

# %%
# working on crime data from Data.lacity.org
# Save path to data set in a variable

#2016
crimeDataFile2016 = "source/CrimeData/2016_Crime_Data_LA.csv"
# Use Pandas to read data
crimeDataFile2016_pd = pd.read_csv(crimeDataFile2016)
crimeDataFile2016_pd.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID  Area Name  \
# 0  160304013      1/1/2016     6/19/2014            900        3  Southwest
# 1  151101012      1/1/2016    12/30/2015           1540       11  Northeast
# 2  151101014      1/1/2016    12/31/2015           1435       11  Northeast
# 3  151601465      1/1/2016      1/1/2015           1900       16   Foothill
# 4  151601469      1/1/2016    12/30/2015           1100       16   Foothill
#
#    Reporting District  Crime Code                      Crime Code Description  \
# 0                 333         668  EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
# 1                1132         310                                    BURGLARY
# 2                1113         442    SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 3                1613         623                     BATTERY POLICE (SIMPLE)
# 4                1672         310                                    BURGLARY
#
# ...

# %%
# print(foreclosureDataFile2019_pd['APN'].count())
# print(crimeDataFile2019_pd['DR Number'].count())
# Out:
# 2547
# 1076

# %%
#get total number of foreclosures and total number of crimes for 2018, 2017, 2016

###
#get total number of foreclosures for 2018, 2017, 2016
totalForeclosureNum=[]
foreclosureYear=[]

#2019, foreclosure
# totalForeclosureNum.append(foreclosureDataFile2019_pd['APN'].count())
# foreYear='2019'
# foreclosureYear.append(int(foreYear))

#2018, foreclosure
totalForeclosureNum.append(foreclosureDataFile2018_pd['APN'].count())
foreYear='2018'
foreclosureYear.append(int(foreYear))

#2017, foreclosure
totalForeclosureNum.append(foreclosureDataFile2017_pd['APN'].count())
foreYear='2017'
foreclosureYear.append(int(foreYear))

#2016, foreclosure
totalForeclosureNum.append(foreclosureDataFile2016_pd['APN'].count())
foreYear='2016'
foreclosureYear.append(int(foreYear))

print(f'foreclosure:  {totalForeclosureNum}, {foreclosureYear}')


###
#get total number of crimes for 2018, 2017, 2016

totalCrimeNum=[]
crimeYear=[]

#2019, crime
# totalCrimeNum.append(crimeDataFile2019_pd['DR Number'].count())
# criYear='2019'
# crimeYear.append(int(criYear))

#2018, crime
totalCrimeNum.append(crimeDataFile2018_pd['DR Number'].count())
criYear='2018'
crimeYear.append(int(criYear))

#2017, crime
totalCrimeNum.append(crimeDataFile2017_pd['DR Number'].count())
criYear='2017'
crimeYear.append(int(criYear))

#2016, crime
totalCrimeNum.append(crimeDataFile2016_pd['DR Number'].count())
criYear='2016'
crimeYear.append(int(criYear))

print(f'crime: {totalCrimeNum}, {crimeYear}')

## create new data frame for foreclosure, crime, and unemployment for 2018, 2017_2016
fore_crime_unemp_2016_2018= {'Year': foreclosureYear,'totalForeclosureNum': totalForeclosureNum, 'totalCrimeNum' : totalCrimeNum,  'UnemploymentRate' : unemploymentRateList}
fore_crime_unemp_2016_2018_df = pd.DataFrame(fore_crime_unemp_2016_2018)
fore_crime_unemp_2016_2018_df
fore_crime_unemp_2016_2018_df.to_csv("output/fore_crime_unemp_2016_2018.csv", index=False, header=True)
# Out:
# foreclosure:  [2547, 3112, 5424, 7638], [2019, 2018, 2017, 2016]
# crime: [1076, 70044, 231055, 225187], [2019, 2018, 2017, 2016]

# %%
fore_crime_unemp_2016_2018_df
# Out:
#    Year  totalForeclosureNum  totalCrimeNum UnemploymentRate
# 0  2019                 2547           1076            4.10%
# 1  2018                 3112          70044            4.70%
# 2  2017                 5424         231055            4.80%
# 3  2016                 7638         225187            5.30%

# %%
###
#get total number of crimes for 2018, 2017, 2016

totalCrimeNum=[]
crimeYear=[]

#2019, crime
# totalCrimeNum.append(crimeDataFile2019_pd['DR Number'].count())
# criYear='2019'
# crimeYear.append(int(criYear))

#2018, crime
totalCrimeNum.append(crimeDataFile2018_pd['DR Number'].count())
criYear='2018'
crimeYear.append(int(criYear))

#2017, crime
totalCrimeNum.append(crimeDataFile2017_pd['DR Number'].count())
criYear='2017'
crimeYear.append(int(criYear))

#2016, crime
totalCrimeNum.append(crimeDataFile2016_pd['DR Number'].count())
criYear='2016'
crimeYear.append(int(criYear))

print(f'crime: {totalCrimeNum}, {crimeYear}')

## create new data frame for foreclosure, crime, and unemployment for 2018, 2017_2016
fore_crime_unemp_2016_2018= {'Year': foreclosureYear,'totalForeclosureNum': totalForeclosureNum, 'totalCrimeNum' : totalCrimeNum,  'UnemploymentRate' : unemploymentRateList}
fore_crime_unemp_2016_2018_df = pd.DataFrame(fore_crime_unemp_2016_2018)
fore_crime_unemp_2016_2018_df
fore_crime_unemp_2016_2018_df.to_csv("output/fore_crime_unemp_2016_2018.csv", index=False, header=True)
# Out:
# crime: [1076, 70044, 231055, 225187], [2019, 2018, 2017, 2016]

# %%
###
#year vs unemployment rate Plot
# Build a scatter plot for each data type

totalForeclosureNumForPlot = []
for y in fore_crime_unemp_2016_2018_df["totalForeclosureNum"]:
    print(y)
   # print(x.replace(",", ""))
    #y = y.replace(",", "")
    totalForeclosureNumForPlot.append(int(y)/500)
print(f' totalForeclosureNumForPlot: {totalForeclosureNumForPlot}')


###
#year vs unemployment rate Plot
# Build a scatter plot for each data type

totalCrimeNumForPlot = []
for z in fore_crime_unemp_2016_2018_df["totalCrimeNum"]:
    print(z)
   # print(x.replace(",", ""))
    #y = y.replace(",", "")
    totalCrimeNumForPlot.append(int(z)/10000)
print(f' totalCrimeNumForPlot: {totalCrimeNumForPlot}')
# Out:
# 2547
# 3112
# 5424
# 7638
#  totalForeclosureNumForPlot: [5.094, 6.224, 10.848, 15.276]
# 1076
# 70044
# 231055
# 225187
#  totalCrimeNumForPlot: [0.1076, 7.0044, 23.1055, 22.5187]

# %%
###
# Plot both of these lines so that they will appear on our final chart

# Create our x_axis list
#x_axis = np.arange(2016, 4, 1)
#y_axis = np.arange(0, 4, 5)
x_axis = fore_crime_unemp_2016_2018_df["Year"]
plt.plot(x_axis, totalForeclosureNumForPlot)
plt.plot(x_axis, totalCrimeNumForPlot)
plt.plot(x_axis, fore_crime_unemp_2016_2018_df['UnemploymentRate'])

# Incorporate the other graph properties
plt.title("LA City Unemployment Rate, TotalForeclosureNum and TotalCrimeNum  (2016-2018)")
plt.ylabel("Unemployment Rate (%)")
plt.xlabel("Year")
plt.grid(True)
plt.xlim(2015,2020)
plt.ylim(-2, 26)

plt.show()

# %%
print("Here")
# Out:
# Here

# %%
###
# Plot both of these lines so that they will appear on our final chart

# Create our x_axis list
#x_axis = np.arange(2016, 4, 1)
#y_axis = np.arange(0, 4, 5)
x_axis = fore_crime_unemp_2016_2018_df["Year"]
plt.plot(x_axis, fore_crime_unemp_2016_2018_df["totalForeclosureNum"])
#plt.plot(x_axis, totalCrimeNumForPlot)
#plt.plot(x_axis, fore_crime_unemp_2016_2019_df['UnemploymentRate'])

# Incorporate the other graph properties
plt.title("LA, Total Number of Foreclosure (2016-2018)")
plt.ylabel("total Number of Foreclosure")
plt.xlabel("Year")
plt.grid(True)
plt.xlim(2015,2020)
plt.ylim(2000, 8000)

plt.show()

# %%
###
# Plot both of these lines so that they will appear on our final chart

# Create our x_axis list
#x_axis = np.arange(2016, 4, 1)
#y_axis = np.arange(0, 4, 5)
x_axis = fore_crime_unemp_2016_2018_df["Year"]
plt.plot(x_axis, fore_crime_unemp_2016_2018_df["totalCrimeNum"])
#plt.plot(x_axis, totalCrimeNumForPlot)
#plt.plot(x_axis, fore_crime_unemp_2016_2019_df['UnemploymentRate'])

# Incorporate the other graph properties
plt.title("LA, Total Number of Crime (2016-2018)")
plt.ylabel("total Number of Crime")
plt.xlabel("Year")
plt.grid(True)
plt.xlim(2015,2019)
plt.ylim(0, 300000)

plt.show()

# %%
###
# Plot both of these lines so that they will appear on our final chart

# Create our x_axis list
#x_axis = np.arange(2016, 4, 1)
#y_axis = np.arange(0, 4, 5)
x_axis = fore_crime_unemp_2016_2018_df["Year"]
#plt.plot(x_axis, fore_crime_unemp_2016_2019_df["totalForeclosureNum"])
#plt.plot(x_axis, totalCrimeNumForPlot)
plt.plot(x_axis, fore_crime_unemp_2016_2018_df['UnemploymentRate'])

# Incorporate the other graph properties
plt.title("LA, Unemployment Rate (2016-2018)")
plt.ylabel("Unemployment Rate(%)")
plt.xlabel("Year")
plt.grid(True)
plt.xlim(2015,2019)
plt.ylim(-2, 6)

plt.show()

# %%
###
# Plot both of these lines so that they will appear on our final chart

# Create our x_axis list
#x_axis = np.arange(2016, 4, 1)
#y_axis = np.arange(0, 4, 5)
x_axis = fore_crime_unemp_2016_2018_df["Year"]
plt.plot(x_axis, totalForeclosureNumForPlot)
#plt.plot(x_axis, totalCrimeNumForPlot)
#plt.plot(x_axis, fore_crime_unemp_2016_2019_df['UnemploymentRate'])

# Incorporate the other graph properties
plt.title("LA City Unemployment Rate, TotalForeclosureNum and TotalCrimeNum  (2016-2018)")
plt.ylabel("Unemployment Rate (%)")
plt.xlabel("Year")
plt.grid(True)
plt.xlim(2015,2019)
plt.ylim(-2, 26)

plt.show()

# %%
###
# Plot both of these lines so that they will appear on our final chart

# Create our x_axis list
#x_axis = np.arange(2016, 4, 1)
#y_axis = np.arange(0, 4, 5)
x_axis = fore_crime_unemp_2016_2018_df["Year"]
plt.plot(x_axis, totalForeclosureNumForPlot)
plt.plot(x_axis, totalCrimeNumForPlot)
plt.plot(x_axis, fore_crime_unemp_2016_2018_df['UnemploymentRate'])

# Incorporate the other graph properties
plt.title("LA City Unemployment Rate, TotalForeclosureNum and TotalCrimeNum  (2016-2018)")
plt.ylabel("Unemployment Rate (%)")
plt.xlabel("Year")
plt.grid(True)
plt.xlim(2015,2019)
plt.ylim(-2, 26)

plt.show()

# %%
print("working on grouping crime data by ocurredDate")
# Out:
# working on grouping crime data by ocurredDate

# %%
###
### group crime data by ocurredDate

occurredDate=[]
occurredMonth=[]
occurredDay=[]
occurredYear=[]

splitedCccurredDate=[]

#totalCount2019=0
totalCount2018=0
totalCount2017=0
totalCount2016=0

#2019
# for index, row in crimeDataFile2018_pd.iterrows():
#     splitedCccurredDate=[]
#     occurredDate.append(row['Date Occurred'])
#     #print(row['Date Occurred'])
#     splitedCccurredDate.append(row['Date Occurred'].split( "/"))
#     #print(splitedCccurredDate[0][2])
# #     if(splitedCccurredDate[0][2] == "2019"):
# #         totalCount2019 += 1
#     if(splitedCccurredDate[0][2] == "2018"):    
#         totalCount2018 += 1
#     elif(splitedCccurredDate[0][2] == "2017"):    
#         totalCount2017 += 1
#     elif(splitedCccurredDate[0][2] == "2016"):    
#         totalCount2016 += 1
#2018
for index, row in crimeDataFile2018_pd.iterrows():
    splitedCccurredDate=[]
    occurredDate.append(row['Date Occurred'])
    #print(row['Date Occurred'])
    splitedCccurredDate.append(row['Date Occurred'].split( "/"))
    #print(splitedCccurredDate[0][2])
#     if(splitedCccurredDate[0][2] == "2019"):
#         totalCount2019 += 1
    if(splitedCccurredDate[0][2] == "2018"):    
        totalCount2018 += 1
    elif(splitedCccurredDate[0][2] == "2017"):    
        totalCount2017 += 1
    elif(splitedCccurredDate[0][2] == "2016"):    
        totalCount2016 += 1
#2017
for index, row in crimeDataFile2017_pd.iterrows():
    splitedCccurredDate=[]
    occurredDate.append(row['Date Occurred'])
    #print(row['Date Occurred'])
    splitedCccurredDate.append(row['Date Occurred'].split( "/"))
    #print(splitedCccurredDate[0][2])
#     if(splitedCccurredDate[0][2] == "2019"):
#         totalCount2019 += 1
    if(splitedCccurredDate[0][2] == "2018"):    
        totalCount2018 += 1
    elif(splitedCccurredDate[0][2] == "2017"):    
        totalCount2017 += 1
    elif(splitedCccurredDate[0][2] == "2016"):    
        totalCount2016 += 1
        
#2016
for index, row in crimeDataFile2016_pd.iterrows():
    splitedCccurredDate=[]
    occurredDate.append(row['Date Occurred'])
    #print(row['Date Occurred'])
    splitedCccurredDate.append(row['Date Occurred'].split( "/"))
    #print(splitedCccurredDate[0][2])
    if(splitedCccurredDate[0][2] == "2019"):
        totalCount2019 += 1
    elif(splitedCccurredDate[0][2] == "2018"):    
        totalCount2018 += 1
    elif(splitedCccurredDate[0][2] == "2017"):    
        totalCount2017 += 1
    elif(splitedCccurredDate[0][2] == "2016"):    
        totalCount2016 += 1
        
print(f'{'{totalCount2018}, {totalCount2017}, {totalCount2016}')
# Out:
# 0, 62307, 229885, 224618

# %%
totalCirmeNumByOccurred = []

#totalCirmeNumByOccurred.append(totalCount2019)
totalCirmeNumByOccurred.append(totalCount2018)
totalCirmeNumByOccurred.append(totalCount2017)
totalCirmeNumByOccurred.append(totalCount2016)
print(totalCirmeNumByOccurred)
# Out:
# [0, 62307, 229885, 224618]

# %%
###Based on OccurredDate
## create new data frame for foreclosure, crime, and unemployment for 2018, 2017_2016
occurred_fore_crime_unemp_2016_2018= {'Year': foreclosureYear,'totalForeclosureNum': totalForeclosureNum, 'totalCrimeNum' : totalCirmeNumByOccurred,  'UnemploymentRate' : unemploymentRateList}
occurred_fore_crime_unemp_2016_2018_df = pd.DataFrame(occurred_fore_crime_unemp_2016_2018)
occurred_fore_crime_unemp_2016_2018_df
occurred_fore_crime_unemp_2016_2018_df.to_csv("output/occurred_fore_crime_unemp_2016_2018.csv", index=False, header=True)

# %%
occurred_fore_crime_unemp_2016_2018_df
# Out:
#    Year  totalForeclosureNum  totalCrimeNum UnemploymentRate
# 0  2019                 2547              0            4.10%
# 1  2018                 3112          62307            4.70%
# 2  2017                 5424         229885            4.80%
# 3  2016                 7638         224618            5.30%

# %%
#Look for AreaName='Los Angeles city' in 2018, 2017, and 2016
#Put those rows in a new dataframe

areaNameList = []
laborForceList = []
employmentList = []
unemploymentNumberList = []
unemploymentRateList = []
yearList = []

# year=2019
# for index, row in unemploymentDataFile2019_pd.iterrows():
#     #print(f'{index}, {row}')
#     ###
#     ###print(index, row['AreaName'], row['Labor-Force'], row['Employment'], row['Unemployment-Number'], row['Unemployment-Rate'])
#         #print(f'{index}, {row}')
#     if (row['AreaName'] == 'Los Angeles city'):
#          #print("here: " + row['AreaName'])
#          areaNameList.append(row['AreaName'])
#          laborForceList.append(row['Labor-Force'])
#          employmentList.append(row['Employment'])
#          unemploymentNumberList.append(row['Unemployment-Number'])
#          unemploymentRateList.append(row['Unemployment-Rate'])
#          yearList.append(int(year))
# #print(areaNameList, yearList)


year=2018
for index, row in unemploymentDataFile2018_pd.iterrows():
    #print(f'{index}, {row}')
    ###
    ###print(index, row['AreaName'], row['Labor-Force'], row['Employment'], row['Unemployment-Number'], row['Unemployment-Rate'])
        #print(f'{index}, {row}')
    if (row['AreaName'] == 'Los Angeles city'):
         #print("here: " + row['AreaName'])
         areaNameList.append(row['AreaName'])
         laborForceList.append(row['Labor-Force'])
         employmentList.append(row['Employment'])
         unemploymentNumberList.append(row['Unemployment-Number'])
         unemploymentRateList.append(row['Unemployment-Rate'])
         yearList.append(int(year))
#print(areaNameList, yearList)


year=2017
for index, row in unemploymentDataFile2017_pd.iterrows():
    #print(f'{index}, {row}')
    ###
    ###print(index, row['AreaName'], row['Labor-Force'], row['Employment'], row['Unemployment-Number'], row['Unemployment-Rate'])
        #print(f'{index}, {row}')
    if (row['AreaName'] == 'Los Angeles city'):
         #print("here: " + row['AreaName'])
         areaNameList.append(row['AreaName'])
         laborForceList.append(row['Labor-Force'])
         employmentList.append(row['Employment'])
         unemploymentNumberList.append(row['Unemployment-Number'])
         unemploymentRateList.append(row['Unemployment-Rate'])
         yearList.append(int(year))
#print(areaNameList, yearList)



year=2016
for index, row in unemploymentDataFile2016_pd.iterrows():
    #print(f'{index}, {row}')
    ###
    ###print(index, row['AreaName'], row['Labor-Force'], row['Employment'], row['Unemployment-Number'], row['Unemployment-Rate'])
        #print(f'{index}, {row}')
    if (row['AreaName'] == 'Los Angeles city'):
         #print("here: " + row['AreaName'])
         areaNameList.append(row['AreaName'])
         laborForceList.append(row['Labor-Force'])
         employmentList.append(row['Employment'])
         unemploymentNumberList.append(row['Unemployment-Number'])
         unemploymentRateList.append(row['Unemployment-Rate'])
         yearList.append(int(year))
print(areaNameList, yearList)

## create new data frame
unemployment_2016_2019_data = {'AreaName': areaNameList,'LaborForce': laborForceList, 'Employment' : employmentList, 'UnemploymentNumber' : unemploymentNumberList, 'UnemploymentRate' : unemploymentRateList, 'Year' : yearList}
unemployment_2016_2019_df = pd.DataFrame(unemployment_2016_2019_data)
unemployment_2016_2019_df
unemployment_2016_2019_df.to_csv("output/combined_unemployment_2016_2019.csv", index=False, header=True)
# Out:
# ['Los Angeles city', 'Los Angeles city', 'Los Angeles city', 'Los Angeles city'] [2019, 2018, 2017, 2016]

# %%
###
###Group crime data by occurredDate
#get total number of crimes for 2019, 2018, 2017, 2016

totalCrimeNumByyOcr=[]
crimeYearByOcr=[]

#2019, crime
totalCrimeNum.append(crimeDataFile2019_pd['DR Number'].count())
criYear='2019'
crimeYear.append(int(criYear))

#2018, crime
totalCrimeNum.append(crimeDataFile2018_pd['DR Number'].count())
criYear='2018'
crimeYear.append(int(criYear))

#2017, crime
totalCrimeNum.append(crimeDataFile2017_pd['DR Number'].count())
criYear='2017'
crimeYear.append(int(criYear))

#2016, crime
totalCrimeNum.append(crimeDataFile2016_pd['DR Number'].count())
criYear='2016'
crimeYear.append(int(criYear))

print(f'crime: {totalCrimeNum}, {crimeYear}')

## create new data frame for foreclosure, crime, and unemployment for 2019, 2018, 2017_2016
fore_crime_unemp_2016_2019= {'Year': foreclosureYear,'totalForeclosureNum': totalForeclosureNum, 'totalCrimeNum' : totalCrimeNum,  'UnemploymentRate' : unemploymentRateList}
fore_crime_unemp_2016_2019_df = pd.DataFrame(fore_crime_unemp_2016_2019)
fore_crime_unemp_2016_2019_df
fore_crime_unemp_2016_2019_df.to_csv("output/fore_crime_unemp_2016_2019.csv", index=False, header=True)
# Out:
# crime: [1076, 70044, 231055, 225187, 1076, 70044, 231055, 225187], [2019, 2018, 2017, 2016, 2019, 2018, 2017, 2016]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-e0d8eb1c32f6> in <module>
#      30 ## create new data frame for foreclosure, crime, and unemployment for 2019, 2018, 2017_2016
#      31 fore_crime_unemp_2016_2019= {'Year': foreclosureYear,'totalForeclosureNum': totalForeclosureNum, 'totalCrimeNum' : totalCrimeNum,  'UnemploymentRate' : unemploymentRateList}
# ---> 32 fore_crime_unemp_2016_2019_df = pd.DataFrame(fore_crime_unemp_2016_2019)
#      33 fore_crime_unemp_2016_2019_df
#      34 fore_crime_unemp_2016_2019_df.to_csv("output/fore_crime_unemp_2016_2019.csv", index=False, header=True)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
# ...

# %%
print("Crime Data")
# Out:
# Crime Data

# %%
#crime data 2019
# Save path to data set in a variable
crimeDataFile2019 = "source/CrimeData/2019_Crime_Data_LA.csv"

# Use Pandas to read data
crimeDataFile2019_pd = pd.read_csv(crimeDataFile2019)
crimeDataFile2019_pd.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0  191104106      1/1/2019     10/3/2015           2030       11    Northeast
# 1  191504002      1/1/2019    11/26/2017           1200       15  N Hollywood
# 2  190204109      1/2/2019     12/1/2016            800        2      Rampart
# 3  190904063      1/2/2019      8/1/2016           1535        9     Van Nuys
# 4  191604029      1/2/2019     6/30/2016            200       16     Foothill
#
#    Reporting District  Crime Code       Crime Code Description  \
# 0                1102         860  BATTERY WITH SEXUAL CONTACT
# 1                1512         354            THEFT OF IDENTITY
# 2                 202         662           BUNCO, GRAND THEFT
# 3                 952         310                     BURGLARY
# 4                1622         121               RAPE, FORCIBLE
#
#                                   MO Codes  ...  \
# 0                           0522 0558 1259  ...
# ...

# %%
crimeDataFile2019_pd.describe()
# Out:
#           DR Number  Time Occurred      Area ID  Reporting District  \
# count  1.076000e+03    1076.000000  1076.000000         1076.000000
# mean   1.911400e+08     962.960967    11.322491         1177.013941
# std    6.118851e+05     609.295108     6.119211          610.483646
# min    1.901006e+08       1.000000     1.000000          105.000000
# 25%    1.906078e+08     600.000000     6.000000          646.000000
# 50%    1.911088e+08    1200.000000    11.000000         1146.000000
# 75%    1.917062e+08    1200.000000    17.000000         1748.250000
# max    1.921110e+08    2359.000000    21.000000         2196.000000
#
#         Crime Code   Victim Age  Premise Code  Weapon Used Code  Crime Code 1  \
# count  1076.000000  1076.000000   1076.000000        374.000000   1076.000000
# mean    518.682156    29.890335    458.008364        402.483957    517.996283
# std     240.648928    20.869229    149.171451         48.488284    239.409036
# ...

# %%
crimeDataFile2019_pd.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Description',
#        'Weapon Used Code', 'Weapon Description', 'Status Code',
#        'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
#        'Crime Code 4', 'Address', 'Cross Street', 'Location '],
#       dtype='object')

# %%
# Save path to data set in a variable
foreclosureDataFile2019 = "source/ForeclosureData/2019_Registered_Foreclosure_Properties.csv"

# Use Pandas to read data
foreclosureDataFile2019_pd = pd.read_csv(foreclosureDataFile2019)
foreclosureDataFile2019_pd.head()
# Out:
#           APN Registered Date       Property Type     Property Address  \
# 0  2126038013        1/2/2019        Multi-Family     18553 W LEMAY ST
# 1  2378025032       1/10/2019  Vacant Residential      3801 N BERRY DR
# 2  2510022010       2/14/2019       Single Family  13420 N WHEELER AVE
# 3  2378025027       1/10/2019       Single Family      3779 N BERRY DR
# 4  2034001021       1/21/2019       Single Family    23727 W WELBY WAY
#
#   Property City Property State  Property Zip  Council District  \
# 0   LOS ANGELES             CA         91335                 3
# 1   LOS ANGELES             CA         91604                 2
# 2   LOS ANGELES             CA         91342                 7
# 3   LOS ANGELES             CA         91604                 2
# 4   LOS ANGELES             CA         91307                12
#
#                               Lender
# 0            NORTH SHORE CAPITAL INC
# 1     Kodiak Capital Management, LLC
# 2                             Celink
# ...

# %%
print("Working on unemployment data")
# Out:
# Working on unemployment data

# %%
# Save path to data set in a variable
data_file = "source/dataSet.csv"

# Use Pandas to read data
data_file_pd = pd.read_csv(data_file)
data_file_pd.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-314ce1f178c6> in <module>
#       3
#       4 # Use Pandas to read data
# ----> 5 data_file_pd = pd.read_csv(data_file)
#       6 data_file_pd.head()
#
# ...

# %%
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CEU0800000003','CEU0800000003'],"startyear":"2014", "endyear":"2019"})
p = requests.post('https://api.bls.gov/publicAPI/v1/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
print(f'{json_data}')
# Out:
# {'status': 'REQUEST_SUCCEEDED', 'responseTime': 170, 'message': [], 'Results': {'series': [{'seriesID': 'CEU0800000003', 'data': [{'year': '2019', 'period': 'M05', 'periodName': 'May', 'latest': 'true', 'value': '27.48', 'footnotes': [{'code': 'P', 'text': 'preliminary'}]}, {'year': '2019', 'period': 'M04', 'periodName': 'April', 'value': '27.58', 'footnotes': [{'code': 'P', 'text': 'preliminary'}]}, {'year': '2019', 'period': 'M03', 'periodName': 'March', 'value': '27.51', 'footnotes': [{}]}, {'year': '2019', 'period': 'M02', 'periodName': 'February', 'value': '27.57', 'footnotes': [{}]}, {'year': '2019', 'period': 'M01', 'periodName': 'January', 'value': '27.49', 'footnotes': [{}]}, {'year': '2018', 'period': 'M12', 'periodName': 'December', 'value': '27.43', 'footnotes': [{}]}, {'year': '2018', 'period': 'M11', 'periodName': 'November', 'value': '27.08', 'footnotes': [{}]}, {'year': '2018', 'period': 'M10', 'periodName': 'October', 'value': '27.03', 'footnotes': [{}]}, {'year': '2
# ...

# %%
print(json.dumps(json_data, indent=4, sort_keys=True))
# Out:
# {
#     "Results": {
#         "series": [
#             {
#                 "data": [
#                     {
#                         "footnotes": [
#                             {
#                                 "code": "P",
#                                 "text": "preliminary"
#                             }
#                         ],
#                         "latest": "true",
#                         "period": "M05",
#                         "periodName": "May",
#                         "value": "27.48",
#                         "year": "2019"
#                     },
#                     {
#                         "footnotes": [
#                             {
#                                 "code": "P",
#                                 "text": "preliminary"
#                             }
#                         ],
#                         "period": "M04",
#                         "periodName": "April",
#                         "value": "27.58",
# ...

# %%
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2011", "endyear":"2014"})
p = requests.post('https://api.bls.gov/publicAPI/v1/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
print(f'{json_data}')
# Out:
# {'status': 'REQUEST_SUCCEEDED', 'responseTime': 123, 'message': [], 'Results': {'series': [{'seriesID': 'CUUR0000SA0', 'data': [{'year': '2014', 'period': 'M12', 'periodName': 'December', 'value': '234.812', 'footnotes': [{}]}, {'year': '2014', 'period': 'M11', 'periodName': 'November', 'value': '236.151', 'footnotes': [{}]}, {'year': '2014', 'period': 'M10', 'periodName': 'October', 'value': '237.433', 'footnotes': [{}]}, {'year': '2014', 'period': 'M09', 'periodName': 'September', 'value': '238.031', 'footnotes': [{}]}, {'year': '2014', 'period': 'M08', 'periodName': 'August', 'value': '237.852', 'footnotes': [{}]}, {'year': '2014', 'period': 'M07', 'periodName': 'July', 'value': '238.250', 'footnotes': [{}]}, {'year': '2014', 'period': 'M06', 'periodName': 'June', 'value': '238.343', 'footnotes': [{}]}, {'year': '2014', 'period': 'M05', 'periodName': 'May', 'value': '237.900', 'footnotes': [{}]}, {'year': '2014', 'period': 'M04', 'periodName': 'April', 'value': '237.072', 'footnot
# ...

# %%
print(json.dumps(json_data, indent=4, sort_keys=True))
# Out:
# {
#     "Results": {
#         "series": [
#             {
#                 "data": [
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M12",
#                         "periodName": "December",
#                         "value": "234.812",
#                         "year": "2014"
#                     },
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M11",
#                         "periodName": "November",
#                         "value": "236.151",
#                         "year": "2014"
#                     },
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M10",
#                         "periodName": "October",
# ...

# %%
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
    
'if 'M01' <= period <= 'M12':'
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(&quot;c:\\temp\\&quot; + seriesId + &quot;.txt&quot;,&quot;w&quot;)
    output.write (x.get_string())
    output.close()
# Out:
#   File "<tokenize>", line 19
#     output = open(&quot;c:\\temp\\&quot; + seriesId + &quot;.txt&quot;,&quot;w&quot;)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2011", "endyear":"2014"})
p = requests.post('https://api.bls.gov/publicAPI/v1/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
    
'if 'M01' <= period <= 'M12':'
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(&quot;c:\\temp\\&quot; + seriesId + &quot;.txt&quot;,&quot;w&quot;)
    output.write (x.get_string())
    output.close()
# Out:
#   File "<tokenize>", line 22
#     output = open(&quot;c:\\temp\\&quot; + seriesId + &quot;.txt&quot;,&quot;w&quot;)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2011", "endyear":"2014"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
print(f'{json_data}')
# Out:
# {'status': 'REQUEST_SUCCEEDED', 'responseTime': 136, 'message': [], 'Results': {'series': [{'seriesID': 'CUUR0000SA0', 'data': [{'year': '2014', 'period': 'M12', 'periodName': 'December', 'value': '234.812', 'footnotes': [{}]}, {'year': '2014', 'period': 'M11', 'periodName': 'November', 'value': '236.151', 'footnotes': [{}]}, {'year': '2014', 'period': 'M10', 'periodName': 'October', 'value': '237.433', 'footnotes': [{}]}, {'year': '2014', 'period': 'M09', 'periodName': 'September', 'value': '238.031', 'footnotes': [{}]}, {'year': '2014', 'period': 'M08', 'periodName': 'August', 'value': '237.852', 'footnotes': [{}]}, {'year': '2014', 'period': 'M07', 'periodName': 'July', 'value': '238.250', 'footnotes': [{}]}, {'year': '2014', 'period': 'M06', 'periodName': 'June', 'value': '238.343', 'footnotes': [{}]}, {'year': '2014', 'period': 'M05', 'periodName': 'May', 'value': '237.900', 'footnotes': [{}]}, {'year': '2014', 'period': 'M04', 'periodName': 'April', 'value': '237.072', 'footnot
# ...

# %%
print(json.dumps(json_data, indent=4, sort_keys=True))
# Out:
# {
#     "Results": {
#         "series": [
#             {
#                 "data": [
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M12",
#                         "periodName": "December",
#                         "value": "234.812",
#                         "year": "2014"
#                     },
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M11",
#                         "periodName": "November",
#                         "value": "236.151",
#                         "year": "2014"
#                     },
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M10",
#                         "periodName": "October",
# ...

# %%
import requests
import json
import prettytable
headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2011", "endyear":"2014"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
print(f'{json_data}')
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
       'if 'M01' <= period <= 'M12':'
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()
# Out:
#   File "<tokenize>", line 20
#     'if 'M01' <= period <= 'M12':'
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import matplotlib.pyplot as plt
import numpy as np
import requests
import json
import prettytable
import pandas as pd
import os
import csv
import time
import datetime

# %%
# Save path to data set in a variable
data_file = "source/2019_Registered_Foreclosure_properties.csv"

# Use Pandas to read data
data_file_2019_pd = pd.read_csv(data_file)
data_file_2019_pd.head()
# Out:
#           APN Registered Date       Property Type     Property Address  \
# 0  2126038013      01/02/2019        Multi-Family     18553 W LEMAY ST
# 1  2378025032      01/10/2019  Vacant Residential      3801 N BERRY DR
# 2  2510022010      02/14/2019       Single Family  13420 N WHEELER AVE
# 3  2378025027      01/10/2019       Single Family      3779 N BERRY DR
# 4  2034001021      01/21/2019       Single Family    23727 W WELBY WAY
#
#   Property City Property State  Property Zip  Council District  \
# 0   LOS ANGELES             CA         91335                 3
# 1   LOS ANGELES             CA         91604                 2
# 2   LOS ANGELES             CA         91342                 7
# 3   LOS ANGELES             CA         91604                 2
# 4   LOS ANGELES             CA         91307                12
#
#                               Lender      Lender Contact  ...  \
# 0            NORTH SHORE CAPITAL INC     MASSOUD SHARIFI  ...
# ...

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime
import os
import csv
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %%
cities.sort()
print(f'{cities}')
# Out:
# ['abha', 'aden', 'adrar', 'ahipara', 'airai', 'aitape', 'akcaabat', 'aklavik', 'aksu', 'aktau', 'albany', 'alekseyevka', 'alice springs', 'alofi', 'along', 'altamont', 'altay', 'altonia', 'alugan', 'ambilobe', 'amderma', 'ampanihy', 'amuntai', 'anar darreh', 'ancud', 'andenes', 'aquiraz', 'aras', 'arinos', 'arraial do cabo', 'asfi', 'aswan', 'atar', 'atbasar', 'attawapiskat', 'atuona', 'avarua', 'avera', 'awbari', 'ayagoz', 'ayan', 'aykhal', 'bairiki', 'bakchar', 'balkanabat', 'ballina', 'bambous virieux', 'banjar', 'barentsburg', 'barrow', 'baruun-urt', 'batagay', 'batagay-alyta', 'batemans bay', 'bathsheba', 'baykit', 'belmonte', 'beloha', 'belushya guba', 'bengkulu', 'beni', 'berezniki', 'berlevag', 'bethel', 'bilibino', 'bilma', 'biskamzha', 'blantyre', 'bluff', 'boa vista', 'bonavista', 'bonfim', 'bonnyville', 'bontang', 'bouna', 'boyolangu', 'bredasdorp', 'bria', 'bridlington', 'broken hill', 'buala', 'bubaque', 'buchanan', 'bud', 'bulgan', 'bull savanna', 'bur gabo', 'buraydah
# ...

# %%
###
url = "http://api.openweathermap.org/data/2.5/weather?"
#query_url = url + "appid=" + api_key + "&q=" + city
query_url = url + "appid=" + api_key + "&q=" 
#cities = ["Paris", "London", "Oslo", "Beijing"]
#cities = ["aasiaat", "abalak"]

# set up lists to hold reponse info
id = []
cloud = []
country = []
date = []
humidity =[]
lat = []
lon = []
tempMax_k = []
tempMax_f = []
windSpeed = []
cityList=[]

# Loop through the list of cities and perform a request for data on each
for city in cities: 
        print(f'city is: {city}')
        response = requests.get(query_url + city).json()   
        print(f'{response}')
        try:
           id.append(response['id']),
           cityList.append(response['name']),
           cloud.append(response['clouds']['all'])
           country.append(response['sys']['country'])
           date.append(response['dt'])
           humidity.append(response['main']['humidity'])
           lat.append(response['coord']['lat'])
           lon.append(response['coord']['lon'])
           tempMax_k.append(response['main']['temp_max'])
           tempMax_f.append((response['main']['temp_max'] - 273.15)*9/5+32)
           windSpeed.append(response['wind']['speed'])
        except:
            print(f'not existing: {city}')
            time.sleep(0.2)
        time.sleep(0.2)
#print(f"The latitude information received is: {lat}")
#print(f"The temperature information received is: {tempMax}")


###
# create a data frame from cities, lat, and temp
weather_dict = {
    "city_id": id,
    "City": cityList,
    "Cloudiness": cloud,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lon,
    "Max Temp (Kelvin)": tempMax_k,
    "Max Temp (F)": tempMax_f,    
    "Wind Speed": windSpeed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
# city is: abha
# {'coord': {'lon': 42.5, 'lat': 18.22}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 300.79, 'pressure': 1022, 'humidity': 50, 'temp_min': 298.15, 'temp_max': 303.15}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 200}, 'clouds': {'all': 75}, 'dt': 1559661322, 'sys': {'type': 1, 'id': 7396, 'message': 0.0056, 'country': 'SA', 'sunrise': 1559615605, 'sunset': 1559663003}, 'timezone': 10800, 'id': 110690, 'name': 'Abha', 'cod': 200}
# city is: aden
# ...

# %%
weather_data.count()
# Out:
# city_id              543
# City                 543
# Cloudiness           543
# Country              543
# Date                 543
# Humidity             543
# Lat                  543
# Lng                  543
# Max Temp (Kelvin)    543
# Max Temp (F)         543
# Wind Speed           543
# dtype: int64

# %%
print(type(weather_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
###
unix_time=int(weather_data['Date'].max())
# local_time = time.localtime(unix_time, '%Y%m%d%H%M%S')
#datetime.datetime.today().strftime('%Y-%m-%d').strftime('%Y-%m-%d %H:%M:%S')
dt=datetime.datetime.fromtimestamp(unix_time).strftime('%m/%d/%Y %H:%M:%S')
local_date=dt.split(' ', 1)[0]
local_date
# Out:
# '06/04/2019'

# %%
###
#Latitude vs Temperature Plot

# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], 
            weather_data["Max Temp (F)"],
            edgecolor="black", linewidths=1, marker="o", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature (F) (" + local_date + ")")
plt.ylabel("Max Temperature(F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-60,90)
plt.ylim([20, 120])

# Save the figure
plt.savefig("output_data/Latitude_Temperature.png")

# Show plot
plt.show()

# %%
###
#Latitude vs. Humidity Plot
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], 
            weather_data["Humidity"],
            edgecolor="black", linewidths=1, marker="o", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (" + local_date + ")")
plt.ylabel("Humidity%")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 90])
plt.ylim([-5, 110])
# Save the figure
plt.savefig("output_data/Latitude_Humidity.png")

# Show plot
plt.show()

# %%
###
#Latitude vs. Cloudiness Plot
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], 
            weather_data["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (" + local_date + ")")
plt.ylabel("Cloudiness%")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-70, 90])
plt.ylim([-10, 110])

# Save the figure
plt.savefig("output_data/Latitude_Cloudiness.png")

# Show plot
plt.show()

# %%
###
#Latitude vs. Wind Speed Plot
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], 
            weather_data["Wind Speed"],
            edgecolor="black", linewidths=1, marker="o", alpha=0.7)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (" + local_date + ")")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-60, 90])
plt.ylim([-2, 16])

# Save the figure
plt.savefig("output_data/Latitude_WindSpeed.png")

# Show plot
plt.show()

# %%
weather_data.to_csv(output_data_file, sep=',', index=False)

# %%
print("The end")
# Out:
# The end

# %%
print("below are tests")
# Out:
# below are tests

# %%
###
url = "http://api.openweathermap.org/data/2.5/weather?"
#query_url = url + "appid=" + api_key + "&q=" + city
query_url = url + "appid=" + api_key + "&q=" 
cities = ["Paris", "London", "Oslo", "Beijing"]

# set up lists to hold reponse info
id = []
cityList = []
cloud = []
country = []
date = []
humidity =[]
lat = []
lon = []
tempMax_k = []
tempMax_f = []
windSpeed = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
     response = requests.get(query_url + city).json()    
     id.append(response['id'])
     cityList.append(response['name'])
     cloud.append(response['clouds']['all'])
     country.append(response['sys']['country'])
     date.append(response['dt'])
     humidity.append(response['main']['humidity'])
     lat.append(response['coord']['lat'])
     lon.append(response['coord']['lon'])
     tempMax_k.append(response['main']['temp_max'])
     tempMax_f.append((response['main']['temp_max'] - 273.15)*9/5+32)
     windSpeed.append(response['wind']['speed'])


print(f"The latitude information received is: {lat}")
print(f"The temperature information received in kelvin is: {tempMax_k}")


###
# create a data frame from cities, lat, and temp
weather_dict = {
    "city_id": id,
    "City": cityList,
    "Cloudiness": cloud,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lon,
    "Max Temp (Kelvin)": tempMax_k,
    "Max Temp (F)": tempMax_f,
    "Wind Speed": windSpeed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
# The latitude information received is: [48.86, 51.51, 59.91, 39.91]
# The temperature information received in kelvin is: [302.15, 290.37, 292.04, 301.48]
#    city_id     City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  2988507    Paris           0      FR  1559661404        48  48.86    2.35
# 1  2643743   London          90      GB  1559661536        93  51.51   -0.13
# 2  3143244     Oslo          40      NO  1559661622        45  59.91   10.74
# 3  1816670  Beijing           0      CN  1559661349        77  39.91  116.39
#
#    Max Temp (Kelvin)  Max Temp (F)  Wind Speed
# 0             302.15        84.200         6.2
# 1             290.37        62.996         4.1
# 2             292.04        66.002         6.7
# 3             301.48        82.994         1.0

# %%
print("test with one city: Lodon")
# Out:
# test with one city: Lodon

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"
# Build query URL
query_url = url + "appid=" + api_key + "&q=" + city

###
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {weather_json}.")
# Out:
# The weather API responded with: {'coord': {'lon': -0.13, 'lat': 51.51}, 'weather': [{'id': 520, 'main': 'Rain', 'description': 'light intensity shower rain', 'icon': '09d'}, {'id': 310, 'main': 'Drizzle', 'description': 'light intensity drizzle rain', 'icon': '09d'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 288.61, 'pressure': 1003, 'humidity': 93, 'temp_min': 287.04, 'temp_max': 290.37}, 'visibility': 10000, 'wind': {'speed': 4.1, 'deg': 90}, 'rain': {'1h': 0.51}, 'clouds': {'all': 90}, 'dt': 1559661536, 'sys': {'type': 1, 'id': 1414, 'message': 0.0103, 'country': 'GB', 'sunrise': 1559620034, 'sunset': 1559679038}, 'timezone': 3600, 'id': 2643743, 'name': 'London', 'cod': 200}.

# %%
print(json.dumps(weather_json, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 51.51,
#         "lon": -0.13
#     },
#     "dt": 1559661536,
#     "id": 2643743,
#     "main": {
#         "humidity": 93,
#         "pressure": 1003,
#         "temp": 288.61,
#         "temp_max": 290.37,
#         "temp_min": 287.04
#     },
#     "name": "London",
#     "rain": {
#         "1h": 0.51
#     },
#     "sys": {
#         "country": "GB",
#         "id": 1414,
#         "message": 0.0103,
#         "sunrise": 1559620034,
#         "sunset": 1559679038,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light intensity shower rain",
#             "icon": "09d",
#             "id": 520,
#             "main": "Rain"
#         },
#         {
#             "description": "light intensity drizzle rain",
#             "icon": "09d",
#             "id": 310,
# ...

# %%
print(f'city id is: {weather_json["id"]}')
print(f'city is: {weather_json["name"]}')
print(f'coord is: {weather_json["coord"]}')
print(f'lon is: {weather_json["coord"]["lon"]}')
print(f'lat is: {weather_json["coord"]["lat"]}')
print(f'country is: {weather_json["sys"]["country"]}')
# Out:
# city id is: 2643743
# city is: London
# coord is: {'lon': -0.13, 'lat': 51.51}
# lon is: -0.13
# lat is: 51.51
# country is: GB

# %%
print(f'humidity is: {weather_json["main"]["humidity"]}')
print(f'max tempurature in Kelvin is: {weather_json["main"]["temp_max"]}')
print(f'max tempurature in F is: {(weather_json["main"]["temp_max"] - 273.15)*9/5+32}')
print(f'max wind speed is: {weather_json["wind"]["speed"]}')
print(f'clouds is: {weather_json["clouds"]["all"]}')
print(f'date is: {weather_json["dt"]}')
# Out:
# humidity is: 93
# max tempurature in Kelvin is: 290.37
# max tempurature in F is: 62.99600000000005
# max wind speed is: 4.1
# clouds is: 90
# date is: 1559661536

# %%
print("end of the tests")
# Out:
# end of the tests

# %%
print("below are pre-provided")
# Out:
# below are pre-provided

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | bisignano
# Processing Record 4 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | ashland
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | haines junction
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | salalah
# Processing Record 16 of Set 1 | port macquarie
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | srednekolymsk
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
