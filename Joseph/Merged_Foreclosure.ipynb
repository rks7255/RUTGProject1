# %%
import pandas as pd
import requests
import json
import numpy as np
import reverse_geocoder as rg
import csv
import os

# %%
forcl_six_path = "Resources/2016_Registered_Foreclosure_Properties.csv"
forcl_six_df = pd.read_csv(forcl_six_path)
forcl_six_df.dtypes

six=forcl_six_df.dropna(subset=["RegisteredDate"])
forcl_six_df["RegisteredDate"]= forcl_six_df["RegisteredDate"].astype('datetime64[ns]')





forcl_seven_path = "Resources/2017_Registered_Foreclosure_Properties.csv"
forcl_seven_df = pd.read_csv(forcl_seven_path)

seven=forcl_seven_df.dropna(subset=["RegisteredDate"])
forcl_seven_df["RegisteredDate"]= forcl_seven_df["RegisteredDate"].astype('datetime64[ns]')


forcl_eight_path = "Resources/2018_Registered_Foreclosure_Properties.csv"
forcl_eight_df = pd.read_csv(forcl_eight_path)

eight=forcl_eight_df.dropna(subset=["RegisteredDate"])
forcl_eight_df["RegisteredDate"]= forcl_eight_df["RegisteredDate"].astype('datetime64[ns]')

forcl_eight_df.drop(columns=['APN','Lender', 'LenderContact', 'LenderContactPhone', 'PropertyManagement',
                           'PropertyManagementContact', 'PropertyManagementAddress',
                           'PropertyMgmtContactPhone', 'Neighborhood Councils (Certified)',
                           'LA Specific Plans', 'Precinct Boundaries', 'Council Districts',
                           'Census Tracts', 'Zip Codes'],inplace=True)
forcl_eight_df
forcl_seven_df
forcl_seven_df.columns

forcl_seven_df.drop(columns=['APN','Lender', 'LenderContact', 'LenderContactPhone', 'PropertyManagement',
                            'PropertyManagementContact', 'PropertyManagementAddress',
                            'PropertyMgmtContactPhone'],inplace=True)
forcl_six_df.columns
forcl_six_df.drop(columns=['APN','Lender', 'LenderContact', 'LenderContactPhone', 'PropertyManagement',
                           'PropertyManagementContact', 'PropertyManagementAddress',
                           'PropertyMgmtContactPhone', 'Neighborhood Councils (Certified)',
                           'LA Specific Plans', 'Precinct Boundaries', 'Council Districts',
                           'Census Tracts', 'Zip Codes'],inplace=True)
forcl_eight_df.columns
# forcl_seven_df.columns
# forcl_six_df.columns
# Out:
# Index(['RegisteredDate', 'PropertyType', 'PropertyAddress', 'PropertyCity',
#        'PropertyState', 'PropertyZip', 'CouncilDistrict', 'Unnamed: 21'],
#       dtype='object')

# %%
foreclosure1 =pd.concat([forcl_six_df,forcl_seven_df, forcl_eight_df], sort=False)
foreclosure1.head()
foreclosure1.shape
foreclosure1
foreclosure=foreclosure1.drop(columns=['Unnamed: 21'])
# foreclosure.dropna
# foreclosure

foreclosure.to_csv(r'C:\Users\josep\Project1\Resources\Real_Merged_ForeClosure.csv')
foreclosure
# Out:
#      RegisteredDate   PropertyType  \
# 0        2016-01-02  Single Family
# 1        2016-01-07  Single Family
# 2        2016-11-07  Single Family
# 3        2016-12-14  Single Family
# 4        2016-11-23  Single Family
# 5        2016-11-21  Single Family
# 6        2016-11-30  Single Family
# 7        2016-01-21  Single Family
# 8        2016-04-20  Single Family
# 9        2016-11-09  Single Family
# 10       2016-01-04  Single Family
# 11       2016-04-22  Single Family
# 12       2016-01-04  Single Family
# 13       2016-12-07   Multi-Family
# 14       2016-11-08   Multi-Family
# 15       2016-11-10  Single Family
# 16       2016-11-17  Single Family
# 17       2016-06-24  Single Family
# 18       2016-01-04  Single Family
# 19       2016-11-15  Single Family
# 20       2016-02-07  Single Family
# 21       2016-01-04  Single Family
# 22       2016-03-02  Single Family
# 23       2016-01-07  Single Family
# 24       2016-06-06  Single Family
# ...

# %%
foreclosure= foreclosure[np.isfinite(foreclosure['PropertyZip'])]

foreclosure["PropertyZip"]= foreclosure["PropertyZip"].astype(int)
foreclosure
# Out:
# C:\Users\josep\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      RegisteredDate   PropertyType  \
# 0        2016-01-02  Single Family
# 1        2016-01-07  Single Family
# 2        2016-11-07  Single Family
# 3        2016-12-14  Single Family
# 4        2016-11-23  Single Family
# 5        2016-11-21  Single Family
# 6        2016-11-30  Single Family
# 7        2016-01-21  Single Family
# 8        2016-04-20  Single Family
# 9        2016-11-09  Single Family
# 10       2016-01-04  Single Family
# 11       2016-04-22  Single Family
# 12       2016-01-04  Single Family
# 13       2016-12-07   Multi-Family
# ...

# %%
foreclosure= foreclosure[np.isfinite(foreclosure['CouncilDistrict'])]

foreclosure["CouncilDistrict"]= foreclosure["CouncilDistrict"].astype(int)
foreclosure.head()
# Out:
#   RegisteredDate   PropertyType  \
# 0     2016-01-02  Single Family
# 1     2016-01-07  Single Family
# 2     2016-11-07  Single Family
# 3     2016-12-14  Single Family
# 4     2016-11-23  Single Family
#
#                                      PropertyAddress PropertyCity  \
# 0  17725 W ORNA DR\nLOS ANGELES, CA 91344\n(34.29...  LOS ANGELES
# 1  2695 N LA CUESTA DR\nLOS ANGELES, CA 90046\n(3...  LOS ANGELES
# 2  841 W 148TH ST\nLOS ANGELES, CA 90247\n(33.898...  LOS ANGELES
# 3  11826 W SNELLING ST\nLOS ANGELES, CA 91352\n(3...  LOS ANGELES
# 4          17431 W EMILITA ST\nLOS ANGELES, CA 91316  LOS ANGELES
#
#   PropertyState  PropertyZip  CouncilDistrict
# 0            CA        91344               12
# 1            CA        90046                4
# 2            CA        90247               15
# 3            CA        91352                6
# 4            CA        91316                5

# %%
foreclosure.to_csv(r'C:\Users\josep\Project1\Resources\Real_Merged_ForeClosure.csv')

# %%
foreclosure.head()
# Out:
#   RegisteredDate   PropertyType  \
# 0     2016-01-02  Single Family
# 1     2016-01-07  Single Family
# 2     2016-11-07  Single Family
# 3     2016-12-14  Single Family
# 4     2016-11-23  Single Family
#
#                                      PropertyAddress PropertyCity  \
# 0  17725 W ORNA DR\nLOS ANGELES, CA 91344\n(34.29...  LOS ANGELES
# 1  2695 N LA CUESTA DR\nLOS ANGELES, CA 90046\n(3...  LOS ANGELES
# 2  841 W 148TH ST\nLOS ANGELES, CA 90247\n(33.898...  LOS ANGELES
# 3  11826 W SNELLING ST\nLOS ANGELES, CA 91352\n(3...  LOS ANGELES
# 4          17431 W EMILITA ST\nLOS ANGELES, CA 91316  LOS ANGELES
#
#   PropertyState  PropertyZip  CouncilDistrict
# 0            CA        91344               12
# 1            CA        90046                4
# 2            CA        90247               15
# 3            CA        91352                6
# 4            CA        91316                5

# %%
foreclosure
# Out:
#      RegisteredDate   PropertyType  \
# 0        2016-01-02  Single Family
# 1        2016-01-07  Single Family
# 2        2016-11-07  Single Family
# 3        2016-12-14  Single Family
# 4        2016-11-23  Single Family
# 5        2016-11-21  Single Family
# 6        2016-11-30  Single Family
# 7        2016-01-21  Single Family
# 8        2016-04-20  Single Family
# 9        2016-11-09  Single Family
# 10       2016-01-04  Single Family
# 11       2016-04-22  Single Family
# 12       2016-01-04  Single Family
# 13       2016-12-07   Multi-Family
# 14       2016-11-08   Multi-Family
# 15       2016-11-10  Single Family
# 16       2016-11-17  Single Family
# 17       2016-06-24  Single Family
# 18       2016-01-04  Single Family
# 19       2016-11-15  Single Family
# 20       2016-02-07  Single Family
# 21       2016-01-04  Single Family
# 22       2016-03-02  Single Family
# 23       2016-01-07  Single Family
# 24       2016-06-06  Single Family
# ...
