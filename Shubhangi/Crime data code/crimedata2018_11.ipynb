# %%
import pandas as pd
import numpy as np
import json
import requests
import csv
from datetime import datetime

from config2018_11 import gkey

# %%
crimedata_df = pd.read_csv("../Source/crimedata_2018_11.csv")
#crimedata_df = pd.read_csv("C:\\Users\\Shubha\\Desktop\\Rutegers\\RUTGProject1\\Source\\crimedata16_19.csv")
crimedata_df.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID  Area Name  \
# 0  180311347     4/22/2018      4/9/2018              1        3  Southwest
# 1  180311348     4/22/2018     4/22/2018            100        3  Southwest
# 2  180311355     4/20/2018     4/20/2018           1910        3  Southwest
# 3  180311357     4/20/2018     4/20/2018           1845        3  Southwest
# 4  180311364     4/23/2018     4/23/2018            200        3  Southwest
#
#    Reporting District  Crime Code             Crime Code Description  \
# 0                 374         310                           BURGLARY
# 1                 338         626  INTIMATE PARTNER - SIMPLE ASSAULT
# 2                 321         330              BURGLARY FROM VEHICLE
# 3                 321         330              BURGLARY FROM VEHICLE
# 4                 393         510                   VEHICLE - STOLEN
#
#                    MO Codes          ...           \
# ...

# %%
crimedata_df.count()
# Out:
# DR Number                 760
# Date Reported             760
# Date Occurred             760
# Time Occurred             760
# Area ID                   760
# Area Name                 760
# Reporting District        760
# Crime Code                760
# Crime Code Description    760
# MO Codes                  708
# Victim Age                760
# Victim Sex                709
# Victim Descent            709
# Premise Code              760
# Premise Description       760
# Weapon Used Code          347
# Weapon Description        347
# Status Code               760
# Status Description        760
# Crime Code 1              760
# Crime Code 2               33
# Crime Code 3                1
# Crime Code 4                0
# Address                   760
# Cross Street              125
# Location                  760
# dtype: int64

# %%
crimedata_df.dtypes
crimedata_df["Date Reported"]=pd.to_datetime(crimedata_df["Date Reported"])
# def unix_stamp(date):
#     return  datetime.datetime.strptime(date,"%d/%m/%Y")
crimedata_2018_11_df = crimedata_df[crimedata_df["Date Reported"] > datetime.strptime("2016-01-01", "%Y-%m-%d")]
crimedata_2018_11_df


# crimedata1619_df.shape
crimedata_2018_11_df.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID  Area Name  \
# 0  180311347    2018-04-22      4/9/2018              1        3  Southwest
# 1  180311348    2018-04-22     4/22/2018            100        3  Southwest
# 2  180311355    2018-04-20     4/20/2018           1910        3  Southwest
# 3  180311357    2018-04-20     4/20/2018           1845        3  Southwest
# 4  180311364    2018-04-23     4/23/2018            200        3  Southwest
#
#    Reporting District  Crime Code             Crime Code Description  \
# 0                 374         310                           BURGLARY
# 1                 338         626  INTIMATE PARTNER - SIMPLE ASSAULT
# 2                 321         330              BURGLARY FROM VEHICLE
# 3                 321         330              BURGLARY FROM VEHICLE
# 4                 393         510                   VEHICLE - STOLEN
#
#                    MO Codes          ...           \
# ...

# %%
#Crating new csv for filttered data
crimedata_2018_11_df.to_csv("../Source/crimedata_2018_11_P.csv", index=False, header=True)

#Adding colunmn in new csv of crime data
crimedata_2018_11_df["Zip Codes"] = ""
crimedata_2018_11_df.head()
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID  Area Name  \
# 0  180311347    2018-04-22      4/9/2018              1        3  Southwest
# 1  180311348    2018-04-22     4/22/2018            100        3  Southwest
# 2  180311355    2018-04-20     4/20/2018           1910        3  Southwest
# 3  180311357    2018-04-20     4/20/2018           1845        3  Southwest
# 4  180311364    2018-04-23     4/23/2018            200        3  Southwest
#
#    Reporting District  Crime Code             Crime Code Description  \
# 0                 374         310                           BURGLARY
# 1                 338         626  INTIMATE PARTNER - SIMPLE ASSAULT
# 2                 321         330              BURGLARY FROM VEHICLE
# 3                 321         330              BURGLARY FROM VEHICLE
# 4                 393         510                   VEHICLE - STOLEN
#
#                    MO Codes    ...      Status Code Status Description  \
# ...

# %%
#find out the xip codes after giving values of lat and lng

url = "https://maps.googleapis.com/maps/api/geocode/json?"
params={'key':gkey}
#set the counter for output checking purpose
counter = 1
print("Begining")
for index,row in crimedata_2018_11_df.iterrows():
    location = row["Location "].replace('(', '').replace(')', '')
    params["latlng"] = location
    params["result_type"] = "postal_code"
    response = requests.get(url,params=params).json()
    result = response['results']
    if(len(result)>0):
        if('address_components' in result[0].keys()):
            if(len(result[0]['address_components'])>0):
                if('long_name' in result[0]['address_components'][0].keys()):
                    #print("Updating zipcode for: {}".format(location))
                    print(f"Record : {counter}")
                    crimedata_2018_11_df.loc[index,"Zip Codes"]=result[0]['address_components'][0]['long_name']
                    #counter increment
                    counter+=1
# Out:
# Begining
# Record : 1
# Record : 2
# Record : 3
# Record : 4
# Record : 5
# Record : 6
# Record : 7
# Record : 8
# Record : 9
# Record : 10
# Record : 11
# Record : 12
# Record : 13
# Record : 14
# Record : 15
# Record : 16
# Record : 17
# Record : 18
# Record : 19
# Record : 20
# Record : 21
# Record : 22
# Record : 23
# Record : 24
# Record : 25
# Record : 26
# Record : 27
# Record : 28
# Record : 29
# Record : 30
# Record : 31
# Record : 32
# Record : 33
# Record : 34
# Record : 35
# Record : 36
# Record : 37
# Record : 38
# Record : 39
# Record : 40
# Record : 41
# Record : 42
# Record : 43
# Record : 44
# Record : 45
# Record : 46
# Record : 47
# Record : 48
# Record : 49
# Record : 50
# Record : 51
# Record : 52
# Record : 53
# Record : 54
# Record : 55
# Record : 56
# Record : 57
# Record : 58
# Record : 59
# Record : 60
# Record : 61
# Record : 62
# Record : 63
# Record : 64
# Record : 65
# Record : 66
# Record : 67
# Record : 68
# Record : 69
# Record : 70
# Record : 71
# ...

# %%
crimedata_2018_11_df
# Out:
#      DR Number Date Reported Date Occurred  Time Occurred  Area ID  Area Name  \
# 0    180311347    2018-04-22      4/9/2018              1        3  Southwest
# 1    180311348    2018-04-22     4/22/2018            100        3  Southwest
# 2    180311355    2018-04-20     4/20/2018           1910        3  Southwest
# 3    180311357    2018-04-20     4/20/2018           1845        3  Southwest
# 4    180311364    2018-04-23     4/23/2018            200        3  Southwest
# 5    180311365    2018-04-22     4/22/2018           2025        3  Southwest
# 6    180311366    2018-04-23     4/22/2018           2340        3  Southwest
# 7    180311367    2018-04-21     4/21/2018           1620        3  Southwest
# 8    180311368    2018-04-21     4/20/2018           1730        3  Southwest
# 9    180311373    2018-04-20     4/19/2018           2130        3  Southwest
# 10   180311374    2018-04-21     4/21/2018           1540        3  Southwest
# ...

# %%
crimedata_2018_11_df.to_csv("../Source/crimedata_2018_11_P.csv", index=False, header=True)

# %%
crimedata2018_11 = pd.read_csv("../Source/crimedata_2018_11_P.csv")
crimedata2018_11.count()
# Out:
# DR Number                 760
# Date Reported             760
# Date Occurred             760
# Time Occurred             760
# Area ID                   760
# Area Name                 760
# Reporting District        760
# Crime Code                760
# Crime Code Description    760
# MO Codes                  708
# Victim Age                760
# Victim Sex                709
# Victim Descent            709
# Premise Code              760
# Premise Description       760
# Weapon Used Code          347
# Weapon Description        347
# Status Code               760
# Status Description        760
# Crime Code 1              760
# Crime Code 2               33
# Crime Code 3                1
# Crime Code 4                0
# Address                   760
# Cross Street              125
# Location                  760
# Zip Codes                 760
# dtype: int64
