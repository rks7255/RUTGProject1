# %%
import os
import glob
import pandas as pd
import numpy as np
os.chdir("../PSource")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
#combined_csv.to_csv( "combined_crime_data.csv", index=False, encoding='utf-8-sig')
combined_csv.count()
# Out:
# DR Number                 641378
# Date Reported             641378
# Date Occurred             641378
# Time Occurred             641378
# Area ID                   641378
# Area Name                 641378
# Reporting District        641378
# Crime Code                641378
# Crime Code Description    641378
# MO Codes                  569496
# Victim Age                641378
# Victim Sex                576283
# Victim Descent            576267
# Premise Code              641369
# Premise Description       641360
# Weapon Used Code          216790
# Weapon Description        216790
# Status Code               641378
# Status Description        641378
# Crime Code 1              641378
# Crime Code 2               43060
# Crime Code 3                1384
# Crime Code 4                  43
# Address                   641378
# Cross Street              109439
# Location                  641378
# Zip Codes                 509860
# dtype: int64

# %%
# saving combined_csv to csv file
combined_csv.to_csv( "combined_crime_data.csv", index=False, encoding='utf-8-sig')

# %%
cleancombined_csv=pd.read_csv("combined_crime_data.csv")

# %%
cleancombined_csv
# Out:
#           DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 0       160121647.0     8/21/2016     8/21/2016          200.0      1.0
# 1       160121649.0     8/21/2016     8/20/2016         1600.0      1.0
# 2       160121650.0     8/21/2016     8/21/2016           30.0      1.0
# 3       160121654.0     8/21/2016     8/21/2016          930.0      1.0
# 4       160121655.0     8/21/2016     8/21/2016          100.0      1.0
# 5       160121659.0     8/21/2016     8/20/2016         2300.0      1.0
# 6       160121662.0     8/21/2016     8/21/2016          330.0      1.0
# 7       160121665.0     8/21/2016     8/21/2016         1720.0      1.0
# 8       160121666.0     8/21/2016     8/21/2016         2105.0      1.0
# 9       160121668.0     8/21/2016     8/21/2016          100.0      1.0
# 10      160121669.0     8/21/2016     8/21/2016          100.0      1.0
# 11      160121670.0     8/21/2016     8/21/2016          100.0      1.0
# ...

# %%
combined_csv.dtypes
#cleancombined_csv
#combined_csv["Zip Codes"] = combined_csv["Zip Codes"].astype(int)
# Out:
# DR Number                 float64
# Date Reported              object
# Date Occurred              object
# Time Occurred             float64
# Area ID                   float64
# Area Name                  object
# Reporting District        float64
# Crime Code                float64
# Crime Code Description     object
# MO Codes                   object
# Victim Age                float64
# Victim Sex                 object
# Victim Descent             object
# Premise Code              float64
# Premise Description        object
# Weapon Used Code          float64
# Weapon Description         object
# Status Code                object
# Status Description         object
# Crime Code 1              float64
# Crime Code 2              float64
# Crime Code 3              float64
# Crime Code 4              float64
# Address                    object
# Cross Street               object
# Location                   object
# Zip Codes                 float64
# dtype: object

# %%
# converting data of "Zip Codes to int"
cleancombined_csv = cleancombined_csv[np.isfinite(cleancombined_csv['Zip Codes'])]
cleancombined_csv["Zip Codes"]= cleancombined_csv["Zip Codes"].astype(int)
cleancombined_csv.dtypes
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# DR Number                 float64
# Date Reported              object
# Date Occurred              object
# Time Occurred             float64
# Area ID                   float64
# Area Name                  object
# Reporting District        float64
# Crime Code                float64
# Crime Code Description     object
# MO Codes                   object
# Victim Age                float64
# Victim Sex                 object
# Victim Descent             object
# Premise Code              float64
# Premise Description        object
# ...

# %%
# drop null values
cleancombined_csv.dropna(how="any")
# Out:
#           DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 245573  161226995.0     11/4/2016     11/4/2016          630.0     12.0
# 247837  161300655.0     5/14/2016      4/4/2016         1500.0     13.0
# 420124  170516591.0     9/27/2017     9/27/2017          730.0      5.0
# 623093  180300642.0     4/21/2018     4/21/2018           30.0      3.0
#
#           Area Name  Reporting District  Crime Code  \
# 245573  77th Street              1232.0       121.0
# 247837       Newton              1325.0       121.0
# 420124       Harbor               567.0       440.0
# 623093    Southwest               378.0       230.0
#
#                                 Crime Code Description  \
# 245573                                  RAPE, FORCIBLE
# 247837                                  RAPE, FORCIBLE
# 420124              THEFT PLAIN - PETTY ($950 & UNDER)
# 623093  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
#
# ...

# %%
#c=cleancombined_csv.fillna(0)
cleancombined_csv.count()
# Out:
# DR Number                 509860
# Date Reported             509860
# Date Occurred             509860
# Time Occurred             509860
# Area ID                   509860
# Area Name                 509860
# Reporting District        509860
# Crime Code                509860
# Crime Code Description    509860
# MO Codes                  453907
# Victim Age                509860
# Victim Sex                459272
# Victim Descent            459260
# Premise Code              509853
# Premise Description       509844
# Weapon Used Code          173506
# Weapon Description        173506
# Status Code               509860
# Status Description        509860
# Crime Code 1              509860
# Crime Code 2               34610
# Crime Code 3                1105
# Crime Code 4                  34
# Address                   509860
# Cross Street               88234
# Location                  509860
# Zip Codes                 509860
# dtype: int64

# %%
# Drop Columns
cleancombined_csv.drop(columns=['Area ID','Reporting District','Cross Street','MO Codes','Victim Descent','Premise Code','Premise Description',
                        'Status Code','Status Description','Crime Code 1','Crime Code 2','Crime Code 3',
                        'Crime Code 4','Weapon Used Code','Weapon Description'],inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
# Change data type of "Date Occurred" to datetime
cleancombined_csv
cleancombined_csv["Date Occurred"]=pd.to_datetime(cleancombined_csv["Date Occurred"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# take year and month from "Date Occurred"
cleancombined_csv['Date Occurred Year'] = cleancombined_csv['Date Occurred'].apply(lambda yr:yr.year)
#cleancombined_csv['Date Occurred Month/Year']= cleancombined_csv['Date Occurred'].apply(lambda x:x.strftime('%B-%Y') )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
cleancombined_csv["Date Occurred Month/Year"]=pd.to_datetime(cleancombined_csv["Date Occurred Month/Year"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cleancombined_csv.dtypes
# Out:
# DR Number                          float64
# Date Reported                       object
# Date Occurred               datetime64[ns]
# Time Occurred                      float64
# Area Name                           object
# Crime Code                         float64
# Crime Code Description              object
# Victim Age                         float64
# Victim Sex                          object
# Address                             object
# Location                            object
# Zip Codes                            int32
# Date Occurred Year                   int64
# Date Occurred Month/Year    datetime64[ns]
# dtype: object

# %%
cleancombined_csv.to_csv("../Crimedata Output/combined_crime_data.csv", index=False, encoding='utf-8-sig')
